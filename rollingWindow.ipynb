# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import torch
from dnn_model import DnnWOTransformer
from dataset import CustomDataset
from torch.utils.data import DataLoader, Subset
import torch.nn as nn
from sklearn.metrics import ndcg_score
import scipy.stats as stats
import numpy as np

# %%
csv_path = "tables\\zaModel.csv" 
all_data = pd.read_csv(csv_path)
all_data = all_data.fillna(-1)

# %%
categorical_cols = ['constructor', 'driverId', 'race_name',
                                'circuit']

numerical_cols = ['season', 'round', 'position_quali', 'grid',
                  'number_of_laps', 'number_of_corners', 'lap_length', 
                  'AirTemp', 'Humidity', 'Pressure', 'TrackTemp', 
                  'WindSpeed', 'rain_bin', 'wind_direction', 
                  'last_year_time', 'avg_position_last5', 
                  'num_dnfs_last5', 'avg_gained_lost_last5', 
                  'avg_pos_last5', 'avg_pit_duration_last5',
                  'avg_pit_duration_prev_race','avg_pit_duration_prev_driver_race', 
                  'avg_overtakes_prev_season_per_circuit', 'best_qual_time_ms']

target_col = 'position_race'

# %%
for col in categorical_cols:
    if all_data[col].dtype == 'object':  # ako je string tip
        all_data[col], uniques = pd.factorize(all_data[col])
        print(f"Kolona '{col}' kodirana u int. Broj unikatnih vrednosti: {len(uniques)}")
# Out:
# Kolona 'constructor' kodirana u int. Broj unikatnih vrednosti: 16
# Kolona 'driverId' kodirana u int. Broj unikatnih vrednosti: 40
# Kolona 'race_name' kodirana u int. Broj unikatnih vrednosti: 36
# Kolona 'circuit' kodirana u int. Broj unikatnih vrednosti: 31

# %%
all_data[target_col] = all_data[target_col].apply(lambda x: 21-x)
all_data['position_quali'] = all_data[target_col].apply(lambda x: 21-x)
all_data['grid'] = all_data[target_col].apply(lambda x: 21-x)

# %%
batch_size = 2

# %%
embedding_dim = 8
num_numerical = len(numerical_cols)

# %%
dataset = CustomDataset(all_data, target_col, numerical_cols, categorical_cols)
loader_test = DataLoader(dataset, batch_size, shuffle=False)

# %%
embeddings_dict = {
    col: dataset.num_of_cat_features[col]
    for col in categorical_cols
}

# %%
hidden_dim = 128
dropout = 0.1
lr = 0.001

# %%
class ListNetLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred_scores, target_ranks):
        # Convert ranks to relevance (higher = better)
        #max_rank = target_ranks.max(dim=1, keepdim=True)[0]
        relevance = target_ranks #max_rank - target_ranks + 1  # shape: [B, N]

        # Compute probability distributions
        true_prob = torch.softmax(relevance, dim=1)
        pred_log_prob = torch.log_softmax(pred_scores, dim=1)

        # Cross entropy between predicted and true distributions
        loss = -torch.sum(true_prob * pred_log_prob, dim=1).mean()
        return loss

# %%
step_size = 4
train_size = 20
val_size = 2
test_size = 4

# %%
train_idx = 0
valid_idx = train_idx + val_size
test_idx = valid_idx + test_size

# %%
from datetime import datetime
import os
timern = datetime.now().strftime('%d-%m-%Y_%H-%M-%S')
path = f'models_camp\\dnn\\rolling window\\{timern}'
os.mkdir(path)

# %%
path
# Out:
# 'models_camp\\dnn\\rolling window\\30-06-2025_22-53-51'

# %%
model = DnnWOTransformer(embeddings_dict, num_numerical, embedding_dim, hidden_dim=hidden_dim, dropout_p=dropout)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
criterion = ListNetLoss()  
optimizer = torch.optim.SGD(model.parameters(), lr, weight_decay=0.0001)

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode = "max", factor = 0.75, patience = 10)

# %%
val_loss_list = []
ndcg_train = []
loss_list_train = []
loss_list_train = []
ndcg_values_valid = []
ndcg_values_valid_one_epoch = []
window_loss = []
window_ndcg = []

# %%
len(dataset)
# Out:
# 148

# %%
dataset = CustomDataset(all_data, target_col, numerical_cols, categorical_cols)

# %%
num_epochs = 200 + 1

# %%
import matplotlib.pyplot as plt

window_size = 20

# Liste za čuvanje po window-u *po epohi*
all_train_losses = []   # lista listi: svaki element je lista loss-ova po epohama za jedan window
all_valid_losses = []
all_train_ndcgs = []
all_valid_ndcgs = []

for window_start in range(0, len(dataset) - window_size - val_size - test_size + 1, step_size):
    train_idx = window_start
    valid_idx = train_idx + window_size
    test_idx = valid_idx + val_size

    if test_idx + test_size > len(dataset):
        print("Preskačem prozor jer izlazi van dataset-a.")
        break

    train_sub = Subset(dataset, range(train_idx, valid_idx))
    valid_sub = Subset(dataset, range(valid_idx, test_idx))
    test_sub = Subset(dataset, range(test_idx, test_idx + test_size))

    loader_train = DataLoader(train_sub, batch_size, shuffle=False)
    loader_val = DataLoader(valid_sub, batch_size, shuffle=False)
    loader_test = DataLoader(test_sub, batch_size, shuffle=False)

    epoch_train_losses = []
    epoch_valid_losses = []
    epoch_train_ndcgs = []
    epoch_valid_ndcgs = []

    for epoch in range(num_epochs):
        # --- Training ---
        model.train()
        running_loss = 0.0
        ndcg_values = []

        for batch_idx, (cat_features, num_tensor, target, drivers_num, position_quali) in enumerate(loader_train):
            cat_features = {k: v.to(device) for k, v in cat_features.items()}
            num_tensor = num_tensor.to(device)
            target = target.to(device)

            optimizer.zero_grad()
            output = model(cat_features, num_tensor).squeeze(-1)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            true_rank_np = target.cpu().numpy()
            scores_np = output.cpu().detach().numpy()
            for i in range(true_rank_np.shape[0]):
                ndcg = ndcg_score([true_rank_np[i]], [scores_np[i]], k=10)
                ndcg_values.append(ndcg)

        avg_loss = running_loss / len(loader_train)
        avg_ndcg = sum(ndcg_values) / len(ndcg_values)

        epoch_train_losses.append(avg_loss)
        epoch_train_ndcgs.append(avg_ndcg)

        # --- Validation ---
        model.eval()
        val_loss = 0.0
        ndcg_values_valid_one_epoch = []

        with torch.no_grad():
            for batch_idx, (cat_features, num_tensor, target, drivers_num, position_quali) in enumerate(loader_val):
                cat_features = {k: v.to(device) for k, v in cat_features.items()}
                num_tensor = num_tensor.to(device)
                target = target.to(device)

                output = model(cat_features, num_tensor).squeeze(-1)
                loss = criterion(output, target)
                val_loss += loss.item()

                scores_np = output.cpu().numpy()
                true_rank_np = target.cpu().numpy()
                for i in range(true_rank_np.shape[0]):
                    ndcg = ndcg_score([true_rank_np[i]], [scores_np[i]], k=10)
                    ndcg_values_valid_one_epoch.append(ndcg)

        avg_val_loss = val_loss / len(loader_val)
        avg_ndcg_valid = sum(ndcg_values_valid_one_epoch) / len(ndcg_values_valid_one_epoch)

        epoch_valid_losses.append(avg_val_loss)
        epoch_valid_ndcgs.append(avg_ndcg_valid)

        print(f"Window {window_start//window_size+1}, Epoch {epoch+1}/{num_epochs}, "
              f"Train Loss: {avg_loss:.4f}, Train NDCG: {avg_ndcg:.4f}, "
              f"Valid Loss: {avg_val_loss:.4f}, Valid NDCG: {avg_ndcg_valid:.4f}")

    # Čuvamo vrednosti po window-u (lista lista)
    all_train_losses.append(epoch_train_losses)
    all_valid_losses.append(epoch_valid_losses)
    all_train_ndcgs.append(epoch_train_ndcgs)
    all_valid_ndcgs.append(epoch_valid_ndcgs)
# Out:
# Window 1, Epoch 1/201, Train Loss: 2.9980, Train NDCG: 0.6030, Valid Loss: 2.7473, Valid NDCG: 0.7824
# Window 1, Epoch 2/201, Train Loss: 2.9989, Train NDCG: 0.6040, Valid Loss: 2.7370, Valid NDCG: 0.6476
# Window 1, Epoch 3/201, Train Loss: 2.9999, Train NDCG: 0.5862, Valid Loss: 2.7322, Valid NDCG: 0.6251
# Window 1, Epoch 4/201, Train Loss: 2.9985, Train NDCG: 0.5871, Valid Loss: 2.7291, Valid NDCG: 0.6896
# Window 1, Epoch 5/201, Train Loss: 2.9952, Train NDCG: 0.6197, Valid Loss: 2.7290, Valid NDCG: 0.6506
# Window 1, Epoch 6/201, Train Loss: 2.9969, Train NDCG: 0.6483, Valid Loss: 2.7225, Valid NDCG: 0.7975
# Window 1, Epoch 7/201, Train Loss: 2.9984, Train NDCG: 0.6241, Valid Loss: 2.7251, Valid NDCG: 0.8232
# Window 1, Epoch 8/201, Train Loss: 2.9934, Train NDCG: 0.6229, Valid Loss: 2.7168, Valid NDCG: 0.8232
# Window 1, Epoch 9/201, Train Loss: 2.9946, Train NDCG: 0.6165, Valid Loss: 2.7167, Valid NDCG: 0.8234
# Window 1, Epoch 10/201, Train Loss: 2.9911, Train NDCG: 0.6305, Valid Loss: 2.7143, Valid NDCG: 0.8246
# Window 1, Epoch 11/201, Train Loss: 2.9920, Train NDCG: 0.6548, Valid Loss: 2.7204, Valid NDCG: 0.8246
# Window 1, Epoch 12/201, Train Loss: 2.9946, Train NDCG: 0.6249, Valid Loss: 2.9053, Valid NDCG: 0.8365
# Window 1, Epoch 13/201, Train Loss: 2.9931, Train NDCG: 0.6606, Valid Loss: 3.2368, Valid NDCG: 0.7041
# Window 1, Epoch 14/201, Train Loss: 2.9943, Train NDCG: 0.5993, Valid Loss: 3.8727, Valid NDCG: 0.7336
# Window 1, Epoch 15/201, Train Loss: 2.9915, Train NDCG: 0.6592, Valid Loss: 4.8198, Valid NDCG: 0.7340
# Window 1, Epoch 16/201, Train Loss: 2.9954, Train NDCG: 0.6270, Valid Loss: 5.5073, Valid NDCG: 0.6778
# Window 1, Epoch 17/201, Train Loss: 2.9904, Train NDCG: 0.6743, Valid Loss: 6.1032, Valid NDCG: 0.6778
# Window 1, Epoch 18/201, Train Loss: 2.9902, Train NDCG: 0.6336, Valid Loss: 6.3915, Valid NDCG: 0.6778
# Window 1, Epoch 19/201, Train Loss: 2.9917, Train NDCG: 0.6275, Valid Loss: 6.7047, Valid NDCG: 0.6749
# Window 1, Epoch 4/201, Train Loss: 2.9664, Train NDCG: 0.6109, Valid Loss: 3.2264, Valid NDCG: 0.6789
# Window 1, Epoch 5/201, Train Loss: 2.9701, Train NDCG: 0.6348, Valid Loss: 3.2231, Valid NDCG: 0.6789
# Window 1, Epoch 6/201, Train Loss: 2.9723, Train NDCG: 0.6555, Valid Loss: 3.2207, Valid NDCG: 0.6789
# Window 1, Epoch 7/201, Train Loss: 2.9745, Train NDCG: 0.6138, Valid Loss: 3.2178, Valid NDCG: 0.6802
# Window 1, Epoch 8/201, Train Loss: 2.9694, Train NDCG: 0.6212, Valid Loss: 3.2164, Valid NDCG: 0.6802
# Window 1, Epoch 9/201, Train Loss: 2.9613, Train NDCG: 0.6294, Valid Loss: 3.2154, Valid NDCG: 0.6802
# Window 1, Epoch 10/201, Train Loss: 2.9648, Train NDCG: 0.6507, Valid Loss: 3.2136, Valid NDCG: 0.6789
# Window 1, Epoch 11/201, Train Loss: 2.9610, Train NDCG: 0.6606, Valid Loss: 3.2123, Valid NDCG: 0.6802
# Window 1, Epoch 12/201, Train Loss: 2.9666, Train NDCG: 0.6472, Valid Loss: 3.2108, Valid NDCG: 0.6802
# Window 1, Epoch 13/201, Train Loss: 2.9596, Train NDCG: 0.6570, Valid Loss: 3.2097, Valid NDCG: 0.6789
# Window 1, Epoch 14/201, Train Loss: 2.9595, Train NDCG: 0.6710, Valid Loss: 3.2081, Valid NDCG: 0.6789
# Window 1, Epoch 15/201, Train Loss: 2.9629, Train NDCG: 0.6229, Valid Loss: 3.2064, Valid NDCG: 0.6802
# Window 1, Epoch 16/201, Train Loss: 2.9664, Train NDCG: 0.6023, Valid Loss: 3.2047, Valid NDCG: 0.6802
# Window 1, Epoch 17/201, Train Loss: 2.9673, Train NDCG: 0.6126, Valid Loss: 3.2031, Valid NDCG: 0.6802
# Window 1, Epoch 18/201, Train Loss: 2.9635, Train NDCG: 0.6477, Valid Loss: 3.2015, Valid NDCG: 0.6802
# Window 1, Epoch 19/201, Train Loss: 2.9646, Train NDCG: 0.6546, Valid Loss: 3.2001, Valid NDCG: 0.6802
# Window 1, Epoch 20/201, Train Loss: 2.9654, Train NDCG: 0.6748, Valid Loss: 3.1984, Valid NDCG: 0.6802
# Window 1, Epoch 21/201, Train Loss: 2.9627, Train NDCG: 0.6430, Valid Loss: 3.1971, Valid NDCG: 0.6802
# Window 1, Epoch 22/201, Train Loss: 2.9580, Train NDCG: 0.6759, Valid Loss: 3.1954, Valid NDCG: 0.6802
# Window 1, Epoch 23/201, Train Loss: 2.9548, Train NDCG: 0.6445, Valid Loss: 3.1943, Valid NDCG: 0.6789
# Window 1, Epoch 24/201, Train Loss: 2.9644, Train NDCG: 0.6492, Valid Loss: 3.1934, Valid NDCG: 0.6789
# Window 1, Epoch 25/201, Train Loss: 2.9628, Train NDCG: 0.6396, Valid Loss: 3.1921, Valid NDCG: 0.6789
# Window 1, Epoch 26/201, Train Loss: 2.9614, Train NDCG: 0.6727, Valid Loss: 3.1902, Valid NDCG: 0.6789
# Window 1, Epoch 188/201, Train Loss: 2.9353, Train NDCG: 0.6460, Valid Loss: 2.9401, Valid NDCG: 0.7724
# Window 1, Epoch 189/201, Train Loss: 2.9250, Train NDCG: 0.6425, Valid Loss: 2.9390, Valid NDCG: 0.7724
# Window 1, Epoch 190/201, Train Loss: 2.9309, Train NDCG: 0.6645, Valid Loss: 2.9380, Valid NDCG: 0.7744
# Window 1, Epoch 191/201, Train Loss: 2.9283, Train NDCG: 0.6643, Valid Loss: 2.9366, Valid NDCG: 0.7686
# Window 1, Epoch 192/201, Train Loss: 2.9333, Train NDCG: 0.6617, Valid Loss: 2.9353, Valid NDCG: 0.8012
# Window 1, Epoch 193/201, Train Loss: 2.9239, Train NDCG: 0.6725, Valid Loss: 2.9347, Valid NDCG: 0.7630
# Window 1, Epoch 194/201, Train Loss: 2.9209, Train NDCG: 0.6957, Valid Loss: 2.9338, Valid NDCG: 0.7630
# Window 1, Epoch 195/201, Train Loss: 2.9345, Train NDCG: 0.6705, Valid Loss: 2.9324, Valid NDCG: 0.7918
# Window 1, Epoch 196/201, Train Loss: 2.9251, Train NDCG: 0.6723, Valid Loss: 2.9315, Valid NDCG: 0.7557
# Window 1, Epoch 197/201, Train Loss: 2.9258, Train NDCG: 0.6697, Valid Loss: 2.9307, Valid NDCG: 0.7576
# Window 1, Epoch 198/201, Train Loss: 2.9262, Train NDCG: 0.6821, Valid Loss: 2.9296, Valid NDCG: 0.7576
# Window 1, Epoch 199/201, Train Loss: 2.9218, Train NDCG: 0.6741, Valid Loss: 2.9287, Valid NDCG: 0.7767
# Window 1, Epoch 200/201, Train Loss: 2.9243, Train NDCG: 0.6861, Valid Loss: 2.9273, Valid NDCG: 0.7844
# Window 1, Epoch 201/201, Train Loss: 2.9268, Train NDCG: 0.6724, Valid Loss: 2.9261, Valid NDCG: 0.7902
# Window 1, Epoch 1/201, Train Loss: 2.8986, Train NDCG: 0.6826, Valid Loss: 2.8316, Valid NDCG: 0.7639
# Window 1, Epoch 2/201, Train Loss: 2.8981, Train NDCG: 0.6666, Valid Loss: 2.8190, Valid NDCG: 0.7596
# Window 1, Epoch 3/201, Train Loss: 2.9055, Train NDCG: 0.6891, Valid Loss: 2.8113, Valid NDCG: 0.7519
# Window 1, Epoch 4/201, Train Loss: 2.9056, Train NDCG: 0.6706, Valid Loss: 2.8066, Valid NDCG: 0.7519
# Window 1, Epoch 5/201, Train Loss: 2.9049, Train NDCG: 0.7043, Valid Loss: 2.8028, Valid NDCG: 0.7401
# Window 1, Epoch 6/201, Train Loss: 2.9028, Train NDCG: 0.7119, Valid Loss: 2.7994, Valid NDCG: 0.7348
# Window 1, Epoch 7/201, Train Loss: 2.8886, Train NDCG: 0.7042, Valid Loss: 2.7955, Valid NDCG: 0.7100
# Window 1, Epoch 8/201, Train Loss: 2.8929, Train NDCG: 0.7084, Valid Loss: 2.7912, Valid NDCG: 0.7095
# Window 1, Epoch 9/201, Train Loss: 2.8912, Train NDCG: 0.6919, Valid Loss: 2.7875, Valid NDCG: 0.7102
# Window 1, Epoch 10/201, Train Loss: 2.9032, Train NDCG: 0.6652, Valid Loss: 2.7841, Valid NDCG: 0.7111
# Window 1, Epoch 11/201, Train Loss: 2.8949, Train NDCG: 0.6762, Valid Loss: 2.7807, Valid NDCG: 0.7111
# Window 1, Epoch 12/201, Train Loss: 2.8867, Train NDCG: 0.6860, Valid Loss: 2.7772, Valid NDCG: 0.7128
# Window 1, Epoch 13/201, Train Loss: 2.8862, Train NDCG: 0.6844, Valid Loss: 2.7740, Valid NDCG: 0.7142
# Window 1, Epoch 14/201, Train Loss: 2.8905, Train NDCG: 0.6883, Valid Loss: 2.7704, Valid NDCG: 0.7158
# Window 1, Epoch 15/201, Train Loss: 2.8931, Train NDCG: 0.6652, Valid Loss: 2.7667, Valid NDCG: 0.7158
# Window 1, Epoch 16/201, Train Loss: 2.8879, Train NDCG: 0.7262, Valid Loss: 2.7627, Valid NDCG: 0.7166
# Window 1, Epoch 17/201, Train Loss: 2.8917, Train NDCG: 0.6796, Valid Loss: 2.7591, Valid NDCG: 0.7166
# Window 1, Epoch 18/201, Train Loss: 2.8914, Train NDCG: 0.7004, Valid Loss: 2.7559, Valid NDCG: 0.7172
# Window 1, Epoch 19/201, Train Loss: 2.8935, Train NDCG: 0.6885, Valid Loss: 2.7528, Valid NDCG: 0.7388
# Window 1, Epoch 20/201, Train Loss: 2.8841, Train NDCG: 0.6706, Valid Loss: 2.7494, Valid NDCG: 0.7388
# Window 1, Epoch 21/201, Train Loss: 2.8969, Train NDCG: 0.6678, Valid Loss: 2.7463, Valid NDCG: 0.7401
# Window 1, Epoch 22/201, Train Loss: 2.8997, Train NDCG: 0.6627, Valid Loss: 2.7430, Valid NDCG: 0.7401
# Window 1, Epoch 23/201, Train Loss: 2.8907, Train NDCG: 0.6960, Valid Loss: 2.7399, Valid NDCG: 0.7401
# Window 1, Epoch 24/201, Train Loss: 2.8842, Train NDCG: 0.6985, Valid Loss: 2.7370, Valid NDCG: 0.7401
# Window 1, Epoch 25/201, Train Loss: 2.8854, Train NDCG: 0.7092, Valid Loss: 2.7342, Valid NDCG: 0.7401
# Window 1, Epoch 26/201, Train Loss: 2.8876, Train NDCG: 0.6905, Valid Loss: 2.7309, Valid NDCG: 0.7401
# Window 1, Epoch 27/201, Train Loss: 2.8813, Train NDCG: 0.6891, Valid Loss: 2.7276, Valid NDCG: 0.7401
# Window 1, Epoch 28/201, Train Loss: 2.8906, Train NDCG: 0.6824, Valid Loss: 2.7241, Valid NDCG: 0.7401
# Window 1, Epoch 29/201, Train Loss: 2.8869, Train NDCG: 0.6677, Valid Loss: 2.7214, Valid NDCG: 0.7523
# Window 1, Epoch 30/201, Train Loss: 2.8903, Train NDCG: 0.6806, Valid Loss: 2.7200, Valid NDCG: 0.7523
# Window 1, Epoch 31/201, Train Loss: 2.8713, Train NDCG: 0.6907, Valid Loss: 2.7153, Valid NDCG: 0.7523
# Window 1, Epoch 32/201, Train Loss: 2.8814, Train NDCG: 0.6840, Valid Loss: 2.7121, Valid NDCG: 0.7523
# Window 1, Epoch 33/201, Train Loss: 2.8773, Train NDCG: 0.6937, Valid Loss: 2.7088, Valid NDCG: 0.7523
# Window 1, Epoch 34/201, Train Loss: 2.8811, Train NDCG: 0.7088, Valid Loss: 2.7053, Valid NDCG: 0.7523
# Window 1, Epoch 35/201, Train Loss: 2.8761, Train NDCG: 0.7122, Valid Loss: 2.7019, Valid NDCG: 0.7523
# Window 1, Epoch 36/201, Train Loss: 2.8743, Train NDCG: 0.6701, Valid Loss: 2.6987, Valid NDCG: 0.7523
# Window 1, Epoch 37/201, Train Loss: 2.8696, Train NDCG: 0.6740, Valid Loss: 2.6953, Valid NDCG: 0.7574
# Window 1, Epoch 38/201, Train Loss: 2.8700, Train NDCG: 0.6730, Valid Loss: 2.6925, Valid NDCG: 0.7574
# Window 1, Epoch 39/201, Train Loss: 2.8785, Train NDCG: 0.7017, Valid Loss: 2.6900, Valid NDCG: 0.7574
# Window 1, Epoch 40/201, Train Loss: 2.8705, Train NDCG: 0.6910, Valid Loss: 2.6863, Valid NDCG: 0.7574
# Window 1, Epoch 41/201, Train Loss: 2.8632, Train NDCG: 0.6820, Valid Loss: 2.6826, Valid NDCG: 0.7574
# Window 1, Epoch 42/201, Train Loss: 2.8777, Train NDCG: 0.7054, Valid Loss: 2.6797, Valid NDCG: 0.7635
# Window 1, Epoch 43/201, Train Loss: 2.8573, Train NDCG: 0.6939, Valid Loss: 2.6767, Valid NDCG: 0.7696
# Window 1, Epoch 44/201, Train Loss: 2.8775, Train NDCG: 0.6768, Valid Loss: 2.6735, Valid NDCG: 0.7696
# Window 1, Epoch 45/201, Train Loss: 2.8726, Train NDCG: 0.7090, Valid Loss: 2.6709, Valid NDCG: 0.7696
# Window 1, Epoch 46/201, Train Loss: 2.8699, Train NDCG: 0.6754, Valid Loss: 2.6680, Valid NDCG: 0.7696
# Window 1, Epoch 47/201, Train Loss: 2.8716, Train NDCG: 0.6762, Valid Loss: 2.6650, Valid NDCG: 0.7696
# Window 1, Epoch 48/201, Train Loss: 2.8678, Train NDCG: 0.7056, Valid Loss: 2.6619, Valid NDCG: 0.7696
# Window 1, Epoch 49/201, Train Loss: 2.8659, Train NDCG: 0.7032, Valid Loss: 2.6592, Valid NDCG: 0.7696
# Window 1, Epoch 50/201, Train Loss: 2.8701, Train NDCG: 0.6706, Valid Loss: 2.6567, Valid NDCG: 0.7696
# Window 1, Epoch 51/201, Train Loss: 2.8609, Train NDCG: 0.6983, Valid Loss: 2.6539, Valid NDCG: 0.7696
# Window 1, Epoch 52/201, Train Loss: 2.8597, Train NDCG: 0.7000, Valid Loss: 2.6517, Valid NDCG: 0.7696
# Window 1, Epoch 53/201, Train Loss: 2.8579, Train NDCG: 0.6900, Valid Loss: 2.6483, Valid NDCG: 0.7696
# Window 1, Epoch 54/201, Train Loss: 2.8590, Train NDCG: 0.7252, Valid Loss: 2.6452, Valid NDCG: 0.7696
# Window 1, Epoch 55/201, Train Loss: 2.8598, Train NDCG: 0.6846, Valid Loss: 2.6423, Valid NDCG: 0.7696
# Window 1, Epoch 56/201, Train Loss: 2.8648, Train NDCG: 0.7271, Valid Loss: 2.6397, Valid NDCG: 0.7696
# Window 1, Epoch 57/201, Train Loss: 2.8520, Train NDCG: 0.6861, Valid Loss: 2.6369, Valid NDCG: 0.7696
# Window 1, Epoch 58/201, Train Loss: 2.8453, Train NDCG: 0.6998, Valid Loss: 2.6344, Valid NDCG: 0.7696
# Window 1, Epoch 59/201, Train Loss: 2.8531, Train NDCG: 0.7156, Valid Loss: 2.6316, Valid NDCG: 0.7696
# Window 1, Epoch 60/201, Train Loss: 2.8728, Train NDCG: 0.6805, Valid Loss: 2.6301, Valid NDCG: 0.7695
# ...
# Window 7, Epoch 48/201, Train Loss: 2.8318, Train NDCG: 0.6826, Valid Loss: 2.7101, Valid NDCG: 0.6044
# Window 7, Epoch 49/201, Train Loss: 2.8471, Train NDCG: 0.6983, Valid Loss: 2.7102, Valid NDCG: 0.6044
# Window 7, Epoch 50/201, Train Loss: 2.8328, Train NDCG: 0.7148, Valid Loss: 2.7105, Valid NDCG: 0.6044
# Window 7, Epoch 51/201, Train Loss: 2.8197, Train NDCG: 0.7108, Valid Loss: 2.7104, Valid NDCG: 0.6044
# Window 7, Epoch 52/201, Train Loss: 2.8681, Train NDCG: 0.6970, Valid Loss: 2.7109, Valid NDCG: 0.6044
# Window 7, Epoch 53/201, Train Loss: 2.8403, Train NDCG: 0.6848, Valid Loss: 2.7110, Valid NDCG: 0.6044
# Window 7, Epoch 54/201, Train Loss: 2.8318, Train NDCG: 0.6944, Valid Loss: 2.7111, Valid NDCG: 0.6044
# Window 7, Epoch 55/201, Train Loss: 2.8392, Train NDCG: 0.7090, Valid Loss: 2.7113, Valid NDCG: 0.6044
# Window 7, Epoch 56/201, Train Loss: 2.8476, Train NDCG: 0.6705, Valid Loss: 2.7117, Valid NDCG: 0.6044
# Window 7, Epoch 57/201, Train Loss: 2.8381, Train NDCG: 0.7042, Valid Loss: 2.7118, Valid NDCG: 0.6044
# Window 7, Epoch 58/201, Train Loss: 2.8525, Train NDCG: 0.6994, Valid Loss: 2.7123, Valid NDCG: 0.6044
# Window 7, Epoch 59/201, Train Loss: 2.8547, Train NDCG: 0.6818, Valid Loss: 2.7127, Valid NDCG: 0.6044
# Window 7, Epoch 60/201, Train Loss: 2.8630, Train NDCG: 0.6916, Valid Loss: 2.7131, Valid NDCG: 0.6044
# Window 7, Epoch 61/201, Train Loss: 2.8440, Train NDCG: 0.7125, Valid Loss: 2.7133, Valid NDCG: 0.6044
# Window 7, Epoch 62/201, Train Loss: 2.8424, Train NDCG: 0.6751, Valid Loss: 2.7133, Valid NDCG: 0.6044
# Window 7, Epoch 63/201, Train Loss: 2.8383, Train NDCG: 0.6770, Valid Loss: 2.7134, Valid NDCG: 0.6044
# Window 7, Epoch 64/201, Train Loss: 2.8253, Train NDCG: 0.6797, Valid Loss: 2.7133, Valid NDCG: 0.6044
# Window 7, Epoch 65/201, Train Loss: 2.8313, Train NDCG: 0.6979, Valid Loss: 2.7133, Valid NDCG: 0.6044
# Window 7, Epoch 66/201, Train Loss: 2.8402, Train NDCG: 0.6946, Valid Loss: 2.7135, Valid NDCG: 0.6044
Valid Loss: 2.7155, Valid NDCG: 0.6044
# Window 7, Epoch 180/201, Train Loss: 2.8416, Train NDCG: 0.6864, Valid Loss: 2.7156, Valid NDCG: 0.6044
# Window 7, Epoch 181/201, Train Loss: 2.8441, Train NDCG: 0.7060, Valid Loss: 2.7156, Valid NDCG: 0.6044
# Window 7, Epoch 182/201, Train Loss: 2.8350, Train NDCG: 0.7053, Valid Loss: 2.7157, Valid NDCG: 0.6044
# Window 7, Epoch 183/201, Train Loss: 2.8365, Train NDCG: 0.6968, Valid Loss: 2.7156, Valid NDCG: 0.6044
# Window 7, Epoch 184/201, Train Loss: 2.8193, Train NDCG: 0.6696, Valid Loss: 2.7155, Valid NDCG: 0.6044
# Window 7, Epoch 185/201, Train Loss: 2.8175, Train NDCG: 0.6914, Valid Loss: 2.7154, Valid NDCG: 0.6044
# Window 7, Epoch 186/201, Train Loss: 2.8342, Train NDCG: 0.7066, Valid Loss: 2.7156, Valid NDCG: 0.6044
# Window 7, Epoch 187/201, Train Loss: 2.8253, Train NDCG: 0.6904, Valid Loss: 2.7155, Valid NDCG: 0.6044
# Window 7, Epoch 188/201, Train Loss: 2.8483, Train NDCG: 0.7050, Valid Loss: 2.7157, Valid NDCG: 0.6044
# Window 7, Epoch 189/201, Train Loss: 2.8440, Train NDCG: 0.6728, Valid Loss: 2.7158, Valid NDCG: 0.6044
# Window 7, Epoch 190/201, Train Loss: 2.8392, Train NDCG: 0.6942, Valid Loss: 2.7157, Valid NDCG: 0.6044
# Window 7, Epoch 191/201, Train Loss: 2.8300, Train NDCG: 0.7177, Valid Loss: 2.7156, Valid NDCG: 0.6044
# Window 7, Epoch 192/201, Train Loss: 2.8121, Train NDCG: 0.7413, Valid Loss: 2.7153, Valid NDCG: 0.6044
# Window 7, Epoch 193/201, Train Loss: 2.8372, Train NDCG: 0.7075, Valid Loss: 2.7153, Valid NDCG: 0.6044
# Window 7, Epoch 194/201, Train Loss: 2.8221, Train NDCG: 0.7199, Valid Loss: 2.7151, Valid NDCG: 0.6044
# Window 7, Epoch 195/201, Train Loss: 2.8392, Train NDCG: 0.7069, Valid Loss: 2.7151, Valid NDCG: 0.6044
# Window 7, Epoch 196/201, Train Loss: 2.8360, Train NDCG: 0.6831, Valid Loss: 2.7152, Valid NDCG: 0.6044
# Window 7, Epoch 197/201, Train Loss: 2.8162, Train NDCG: 0.7244, Valid Loss: 2.7151, Valid NDCG: 0.6044
# Window 7, Epoch 198/201, Train Loss: 2.8271, Train NDCG: 0.6836, Valid Loss: 2.7150, Valid NDCG: 0.6044
# Window 7, Epoch 199/201, Train Loss: 2.8456, Train NDCG: 0.6942, Valid Loss: 2.7151, Valid NDCG: 0.6044
# Window 7, Epoch 200/201, Train Loss: 2.8164, Train NDCG: 0.7076, Valid Loss: 2.7149, Valid NDCG: 0.6044
# Window 7, Epoch 201/201, Train Loss: 2.8294, Train NDCG: 0.6996, Valid Loss: 2.7149, Valid NDCG: 0.6044

# %%
# --- Plotovanje na kraju svih window-a ---
# Pretvori u numpy za lakše indeksiranje (nije obavezno)
import numpy as np
all_train_losses = np.array(all_train_losses)    # shape = (num_windows, num_epochs)
all_valid_losses = np.array(all_valid_losses)
all_train_ndcgs = np.array(all_train_ndcgs)
all_valid_ndcgs = np.array(all_valid_ndcgs)

epochs = np.arange(1, num_epochs+1)
windows = np.arange(1, all_train_losses.shape[0]+1)

plt.figure(figsize=(14, 10))

# Plot train losses po epochama i window-ima
plt.subplot(2,2,1)
for i in range(all_train_losses.shape[0]):
    plt.plot(epochs, all_train_losses[i], label=f'Window {i+1}')
plt.xlabel('Epoch')
plt.ylabel('Train Loss')
plt.title('Train Loss kroz epohe i window-e')
plt.legend()

# Plot valid losses
plt.subplot(2,2,2)
for i in range(all_valid_losses.shape[0]):
    plt.plot(epochs, all_valid_losses[i], label=f'Window {i+1}')
plt.xlabel('Epoch')
plt.ylabel('Valid Loss')
plt.title('Valid Loss kroz epohe i window-e')
plt.legend()

# Plot train NDCG
plt.subplot(2,2,3)
for i in range(all_train_ndcgs.shape[0]):
    plt.plot(epochs, all_train_ndcgs[i], label=f'Window {i+1}')
plt.xlabel('Epoch')
plt.ylabel('Train NDCG')
plt.title('Train NDCG kroz epohe i window-e')
plt.legend()

# Plot valid NDCG
plt.subplot(2,2,4)
for i in range(all_valid_ndcgs.shape[0]):
    plt.plot(epochs, all_valid_ndcgs[i], label=f'Window {i+1}')
plt.xlabel('Epoch')
plt.ylabel('Valid NDCG')
plt.title('Valid NDCG kroz epohe i window-e')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(window_start)
# Out:
# 120

# %%
len(dataset)
# Out:
# 148

# %%
race_index = 1  # npr. 5. trka (indeks 4)

with torch.no_grad():
    for batch_idx, (cat_features, num_tensor, target, drivers_num, position_quali) in enumerate(loader_test):
        if race_index // batch_size == batch_idx:
            sample_idx = race_index % batch_size  # indeks unutar batcha

            cat_features = {k: v.to(device) for k, v in cat_features.items()}
            num_tensor = num_tensor.to(device)
            target = target.to(device)

            output = model(cat_features, num_tensor).squeeze(-1)

            # Izvuci samo jednu trku iz batcha
            scores = output[sample_idx].cpu().numpy()
            true_ranks = target[sample_idx].cpu().numpy()
            quali_pos = position_quali[sample_idx].numpy()
            driver_ids = drivers_num[sample_idx].numpy()

            # Sortiraj po predikcijama
            pred_order = scores.argsort()

            print(f"Poređenje za trku #{race_index}:\n")
            print(f"{'Poz':<5}{'Vozač':<10}{'Stvarna':<10}{'Predviđena':<12}{'Kvalifikacije':<15}")
            for pos, idx in enumerate(pred_order):
                print(f"{pos+1:<5}{driver_ids[idx]:<10}{true_ranks[idx]:<10}{pos+1:<12}{quali_pos[idx]:<15}")
            break
# Out:
# Poređenje za trku #1:
#
# Poz  Vozač     Stvarna   Predviđena  Kvalifikacije
# 1    11        4.0       1           17
# 2    43        9.0       2           12
# 3    18        10.0      3           11
# 4    14        3.0       4           18
# 5    30        5.0       5           16
# 6    20        14.0      6           7
# 7    33        15.0      7           6
# 8    44        17.0      8           4
# 9    16        18.0      9           3
# 10   55        20.0      10          1
# 11   4         19.0      11          2
# 12   63        16.0      12          5
# 13   81        13.0      13          8
# 14   23        2.0       14          19
# 15   31        8.0       15          13
# 16   10        11.0      16          10
# 17   22        1.0       17          20
# 18   27        12.0      18          9
# 19   24        6.0       19          15
# 20   77        7.0       20          14
